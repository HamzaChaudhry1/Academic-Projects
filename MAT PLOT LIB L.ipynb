# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
# 'Ro' is the red dots on graph for better visuals 
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', linewidth=2)
plt.plot(t, t**2, 'bs', markersize=6)
plt.plot(t, t**3, 'g^', markersize=6)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
x_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
 
plt.bar(x_pos, performance, align='center', alpha=0.5)
plt.xticks(x_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Usage')
plt.title('Programming language usage')
 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# data to plot
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)
 
# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, means_frank, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Frank')
 
rects2 = plt.bar(index + bar_width, means_guido, bar_width,
                 alpha=opacity,
                 color='g',
                 label='Guido')
 
plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width/2, ('A', 'B', 'C', 'D'))
plt.legend()
 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# data to plot
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)

# create plot
#fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.7
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Frank')

rects2 = plt.bar(index, means_guido, bar_width,
alpha=opacity,
bottom=means_frank,
color='g',
label='Guido')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index, ('A', 'B', 'C', 'D'))
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('classic') 

x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 5
n, bins, patches = plt.hist(x, num_bins)
plt.show()

# %%
#!/usr/bin/env python
 
# A complete matplotlib python histogram
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
  
# example data
mu = 100 # mean of distribution
sigma = 15 # standard deviation of distribution
data = mu + sigma * np.random.randn(10000)
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
  
plt.plot(x, p, 'r--')

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ: $\mu=100$, $\sigma=15$')
  
plt.show()

# %%
# %matplotlib inline
import numpy as np 
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

plt.plot(t, t, 'r--', linewidth=2, label="Baseline")
plt.plot(t, t**2, 'bs', markersize=6, label="Squared Line")
plt.plot(t, t**3, 'g^', markersize=6, label="Cubed Line")

plt.xlabel('Sampled time at 200ms intervals')
plt.ylabel('Y')
plt.title('Linear, Squared and Cubed Data')
plt.legend(loc="upper left")
plt.axis([-0.1, 5.1, -1, 120])
plt.show()

# %%
plt.xlabel('Sampled time at 200ms intervals')
plt.ylabel('Y')
plt.title('Linear, Squared and Cubed Data')
plt.legend(loc="upper left")
plt.axis([-0.1, 5.1, -1, 120])
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# SAVING PLOTS AS A PNG FILE CODE

plt.savefig('sample_fig.png')

#PNG IMAGE WILL GENERATE AND BE FOUND UNDER THE MAIN JUPYTER SCREEN

# %%
# scatter PLOT -NON SEQUENTIAL DATA

import numpy as np
import matplotlib.pyplot as plt

x = [1, 2, 3.5, 5, 8, 4, 5.5, 6, 9.3,  3, 4.5, 6,  8.9,  9.2, 7, 3, 8.2, 7, 6, 8.5, 8, 6.3, 5.2]
y = [1, 2, 5, 3, 7, 5, 6, 6, 10, 2, 4, 6.6, 11,  7, 9, 4, 7, 7, 9, 8, 7.5, 7.2, 5.2]

plt.scatter(x, y)
plt.show()

# %%
plt.scatter(xaxis_vals, yaxis_vals, s = bubble_size_vals)
life_exp = [43.828, 76.423, 72.301, ... 73.422, 62.698, 42.38399, 43.487]
gdp_cap = [974.5803384, 5937.029525999998, ... 469.70929810000007]
pop = [31.889923, 3.600523, ... 11.746035, 12.311143]

import matplotlib.pyplot as plt

# Create a bubble chart using pop
plt.scatter(gdp_cap, life_exp, s = pop)

# Customize the plot to include a title and labels
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')

# Display the plot
plt.show()
# Out:
#   File "<ipython-input-21-ac8337036d52>", line 2
#     life_exp = [43.828, 76.423, 72.301, ... 73.422, 62.698, 42.38399, 43.487]
#                                             ^
# SyntaxError: invalid syntax

# %%
life_exp = [43.828, 76.423, 72.301, ... 73.422, 62.698, 42.38399, 43.487]
gdp_cap  = [974.5803384, 5937.029525999998, ... 469.70929810000007]

import matplotlib.pyplot as plt

# Change the line plot below to a scatter plot
plt.scatter(gdp_cap, life_exp)

# Put the x-axis on a logarithmic scale
plt.xscale('log')
plt.show()
# Out:
#   File "<ipython-input-22-b078aaeb3756>", line 1
#     life_exp = [43.828, 76.423, 72.301, ... 73.422, 62.698, 42.38399, 43.487]
#                                             ^
# SyntaxError: invalid syntax
